# %%
import pandas as pd
import numpy as np
import sqlite3 as sql

# %% [markdown]
# <img src = "chinook Tables.png" width="70%"/>

# %%
conn = sql.connect("chinook.db")

# %%
def read_sql(q):
    return pd.read_sql_query(q, conn)

# %%
q = """select * from sqlite_master"""
read_sql(q)
# Out:
#      type                               name             tbl_name  rootpage  \
# 0   table                              album                album         2
# 1   table                             artist               artist         3
# 2   table                           customer             customer         4
# 3   table                           employee             employee         5
# 4   table                              genre                genre         6
# 5   table                            invoice              invoice         7
# 6   table                       invoice_line         invoice_line         8
# 7   table                         media_type           media_type         9
# 8   table                           playlist             playlist        10
# 9   table                     playlist_track       playlist_track        11
# 10  index  sqlite_autoindex_playlist_track_1       playlist_track        12
# ...

# %%
q = """select * from invoice"""

read_sql(q)
# Out:
#      invoice_id  customer_id         invoice_date       billing_address  \
# 0             1           18  2017-01-03 00:00:00          627 Broadway
# 1             2           30  2017-01-03 00:00:00      230 Elgin Street
# 2             3           40  2017-01-05 00:00:00        8, Rue Hanovre
# 3             4           18  2017-01-06 00:00:00          627 Broadway
# 4             5           27  2017-01-07 00:00:00       1033 N Park Ave
# ..          ...          ...                  ...                   ...
# 609         610           55  2020-12-21 00:00:00     421 Bourke Street
# 610         611           52  2020-12-27 00:00:00     202 Hoxton Street
# 611         612           33  2020-12-27 00:00:00        5112 48 Street
# 612         613           20  2020-12-29 00:00:00  541 Del Medio Avenue
# 613         614           53  2020-12-30 00:00:00          113 Lupus St
#
#       billing_city billing_state billing_country billing_postal_code  total  \
# ...

# %%
q = """select * from invoice_line where invoice_id = 1
        """

read_sql(q)
# Out:
#     invoice_line_id  invoice_id  track_id  unit_price  quantity
# 0                 1           1      1158        0.99         1
# 1                 2           1      1159        0.99         1
# 2                 3           1      1160        0.99         1
# 3                 4           1      1161        0.99         1
# 4                 5           1      1162        0.99         1
# 5                 6           1      1163        0.99         1
# 6                 7           1      1164        0.99         1
# 7                 8           1      1165        0.99         1
# 8                 9           1      1166        0.99         1
# 9                10           1      1167        0.99         1
# 10               11           1      1168        0.99         1
# 11               12           1      1169        0.99         1
# 12               13           1      1170        0.99         1
# 13               14           1      1171        0.99         1
# ...

# %%
q = """select i.invoice_id, i.billing_address,il.track_id, il.unit_price from invoice i
        inner join invoice_line il
        on 
        i.invoice_id = il.invoice_id
        where i.invoice_id = 1"""

read_sql(q)
# Out:
#     invoice_id billing_address  track_id  unit_price
# 0            1    627 Broadway      1158        0.99
# 1            1    627 Broadway      1159        0.99
# 2            1    627 Broadway      1160        0.99
# 3            1    627 Broadway      1161        0.99
# 4            1    627 Broadway      1162        0.99
# 5            1    627 Broadway      1163        0.99
# 6            1    627 Broadway      1164        0.99
# 7            1    627 Broadway      1165        0.99
# 8            1    627 Broadway      1166        0.99
# 9            1    627 Broadway      1167        0.99
# 10           1    627 Broadway      1168        0.99
# 11           1    627 Broadway      1169        0.99
# 12           1    627 Broadway      1170        0.99
# 13           1    627 Broadway      1171        0.99
# 14           1    627 Broadway      1172        0.99
# 15           1    627 Broadway      1173        0.99

# %%
q = """pragma table_info(invoice)"""

read_sql(q)
# Out:
#     cid                 name           type  notnull dflt_value  pk
# 0     0           invoice_id        INTEGER        1       None   1
# 1     1          customer_id        INTEGER        1       None   0
# 2     2         invoice_date       DATETIME        1       None   0
# 3     3      billing_address   NVARCHAR(70)        0       None   0
# 4     4         billing_city   NVARCHAR(40)        0       None   0
# 5     5        billing_state   NVARCHAR(40)        0       None   0
# 6     6      billing_country   NVARCHAR(40)        0       None   0
# 7     7  billing_postal_code   NVARCHAR(10)        0       None   0
# 8     8                total  NUMERIC(10,2)        1       None   0
# 9     9                  tax        numeric        0       None   0
# 10   10             subtotal        Numeric        0       None   0

# %%
q = """select alb.title Album_Title, ar.name Artist_Name,
        count(il.track_id) No_Purchased 
        from artist ar
        left join album alb
        on
        alb.artist_id = ar.artist_id
        inner join track t
        on
        t.album_id = alb.album_id
        inner join invoice_line il
        on
        t.track_id = il.track_id
        group by 1
        order by 3 desc"""

read_sql(q)
# Out:
#                           Album_Title              Artist_Name  No_Purchased
# 0                Are You Experienced?             Jimi Hendrix           187
# 1                            Faceless                 Godsmack            96
# 2                           Mezmerize         System Of A Down            93
# 3                            Get Born                      JET            90
# 4                           The Doors                The Doors            83
# ..                                ...                      ...           ...
# 246    Battlestar Galactica, Season 3     Battlestar Galactica             1
# 247  Bartok: Violin & Viola Concertos           Yehudi Menuhin             1
# 248         Bach: Goldberg Variations           Wilhelm Kempff             1
# 249   Arquivo Os Paralamas Do Sucesso  Os Paralamas Do Sucesso             1
# 250               Acústico MTV [live]             Cidade Negra             1
#
# [251 rows x 3 columns]

# %%
q = """Select e1.first_name ||' '|| e1.last_name Employee_Name, e1.title Employee_Title,
        e2.first_name ||' '|| e2.last_name Manager_Name, e2.title Manager_Title
        from employee e1
        left join employee e2
        on
        e1.reports_to = e2.employee_id
        """

read_sql(q)
# Out:
#       Employee_Name       Employee_Title      Manager_Name    Manager_Title
# 0      Andrew Adams      General Manager              None             None
# 1     Nancy Edwards        Sales Manager      Andrew Adams  General Manager
# 2      Jane Peacock  Sales Support Agent     Nancy Edwards    Sales Manager
# 3     Margaret Park  Sales Support Agent     Nancy Edwards    Sales Manager
# 4     Steve Johnson  Sales Support Agent     Nancy Edwards    Sales Manager
# 5  Michael Mitchell           IT Manager      Andrew Adams  General Manager
# 6       Robert King             IT Staff  Michael Mitchell       IT Manager
# 7    Laura Callahan             IT Staff  Michael Mitchell       IT Manager

# %%
q = """select * from employee"""
read_sql(q)
# Out:
#    employee_id last_name first_name                title  reports_to  \
# 0            1     Adams     Andrew      General Manager         NaN
# 1            2   Edwards      Nancy        Sales Manager         1.0
# 2            3   Peacock       Jane  Sales Support Agent         2.0
# 3            4      Park   Margaret  Sales Support Agent         2.0
# 4            5   Johnson      Steve  Sales Support Agent         2.0
# 5            6  Mitchell    Michael           IT Manager         1.0
# 6            7      King     Robert             IT Staff         6.0
# 7            8  Callahan      Laura             IT Staff         6.0
#
#              birthdate            hire_date                      address  \
# 0  1962-02-18 00:00:00  2016-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2016-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2017-04-01 00:00:00                1111 6 Ave SW
# ...

# %%
q = """select c.first_name || ' ' || c.last_name Customer_Name, c.country Countries,
        sum(inv.total) Total_spend
        from customer c
        inner join invoice inv
        on
        c.customer_id = inv.customer_id
        group by 1"""

read_sql(q)
# Out:
#             Customer_Name       Countries  Total_spend
# 0          Aaron Mitchell          Canada        70.29
# 1         Alexandre Rocha          Brazil        69.30
# 2           Astrid Gruber         Austria        69.30
# 3            Bjørn Hansen          Norway        72.27
# 4         Camille Bernard          France        79.20
# 5            Daan Peeters         Belgium        60.39
# 6              Dan Miller             USA        95.04
# 7         Diego Gutiérrez       Argentina        39.60
# 8      Dominique Lefebvre          France        72.27
# 9         Eduardo Martins          Brazil        60.39
# 10         Edward Francis          Canada        91.08
# 11         Ellie Sullivan          Canada        75.24
# 12             Emma Jones  United Kingdom        68.31
# 13          Enrique Muñoz           Spain        98.01
# 14         Fernanda Ramos          Brazil       106.92
# 15           Frank Harris             USA        74.25
# ...

# %%
q = """with total_purchases as 
        (select c.first_name || ' ' || c.last_name Customer_Name, c.country Countries,
        sum(inv.total) Total_spend
        from customer c
        inner join invoice inv
        on
        c.customer_id = inv.customer_id
        group by 1)
        
        select Countries,Customer_Name,max(Total_spend) Top_Spend from total_purchases
        group by 1
        order by 3 desc
        """

read_sql(q)
# Out:
#          Countries          Customer_Name  Top_Spend
# 0   Czech Republic  František Wichterlová     144.54
# 1          Ireland          Hugh O'Reilly     114.84
# 2            India           Manoj Pareek     111.87
# 3           Brazil         Luís Gonçalves     108.90
# 4         Portugal         João Fernandes     102.96
# 5           France           Wyatt Girard      99.99
# 6           Canada      François Tremblay      99.99
# 7   United Kingdom            Phil Hughes      98.01
# 8              USA             Jack Smith      98.01
# 9            Spain          Enrique Muñoz      98.01
# 10           Chile             Luis Rojas      97.02
# 11         Germany        Fynn Zimmermann      94.05
# 12       Australia            Mark Taylor      81.18
# 13         Finland       Terhi Hämäläinen      79.20
# 14         Hungary        Ladislav Kovács      78.21
# 15          Poland       Stanisław Wójcik      76.23
# 16          Sweden       Joakim Johansson      75.24
# ...

# %%
q = """select c.first_name || ' ' || c.last_name Customer_Name, c.country Countries,
        count(inv.invoice_id) no_of_purchases,
        sum(inv.total) Total_spend,
        
        case
        when sum(inv.total) < 40 then "Small Spender"
        when sum(inv.total) > 100 then "Big Spender"
        else "Regular"
        end as Spender
        
        from customer c
        inner join invoice inv
        on
        c.customer_id = inv.customer_id
        group by 1"""

read_sql(q)
# Out:
#             Customer_Name       Countries  no_of_purchases  Total_spend  \
# 0          Aaron Mitchell          Canada                8        70.29
# 1         Alexandre Rocha          Brazil               10        69.30
# 2           Astrid Gruber         Austria                9        69.30
# 3            Bjørn Hansen          Norway                9        72.27
# 4         Camille Bernard          France                9        79.20
# 5            Daan Peeters         Belgium                7        60.39
# 6              Dan Miller             USA               12        95.04
# 7         Diego Gutiérrez       Argentina                5        39.60
# 8      Dominique Lefebvre          France                9        72.27
# 9         Eduardo Martins          Brazil               12        60.39
# 10         Edward Francis          Canada               13        91.08
# 11         Ellie Sullivan          Canada               12        75.24
# ...

# %%
q = """select distinct(name) from genre"""

read_sql(q)
# Out:
#                   name
# 0                 Rock
# 1                 Jazz
# 2                Metal
# 3   Alternative & Punk
# 4        Rock And Roll
# 5                Blues
# 6                Latin
# 7               Reggae
# 8                  Pop
# 9           Soundtrack
# 10          Bossa Nova
# 11      Easy Listening
# 12         Heavy Metal
# 13            R&B/Soul
# 14   Electronica/Dance
# 15               World
# 16         Hip Hop/Rap
# 17     Science Fiction
# 18            TV Shows
# 19    Sci Fi & Fantasy
# 20               Drama
# 21              Comedy
# 22         Alternative
# 23           Classical
# 24               Opera

# %% [markdown]
# Punk,Pop,Blues,Hip Hop

# %%
q = """with USA_Sale as
        (select g.name Genre_Name, count(t.track_id) Total_Sales from genre g
        inner join track t
        on 
        g.genre_id = t.genre_id
        inner join invoice_line il
        on
        t.track_id = il.track_id
        inner join invoice i
        on
        il.invoice_id = i.invoice_id
        inner join customer c
        on
        c.customer_id = i.customer_id
        where c.country == "USA"
        group by 1
        order by 2 desc)
        --- select sum(Total_Sales) from USA_sale;
        select genre_name, total_sales, 
        (cast(total_sales as float)/(select sum(Total_Sales) from USA_sale))*100 Percentage_Sale
        from usa_sale
        limit 10;
        """

df = read_sql(q)
df
# Out:
#            Genre_Name  Total_Sales  Percentage_Sale
# 0                Rock          561        53.377735
# 1  Alternative & Punk          130        12.369172
# 2               Metal          124        11.798287
# 3            R&B/Soul           53         5.042816
# 4               Blues           36         3.425309
# 5         Alternative           35         3.330162
# 6                 Pop           22         2.093245
# 7               Latin           22         2.093245
# 8         Hip Hop/Rap           20         1.902950
# 9                Jazz           14         1.332065

# %%
import matplotlib.pyplot as plt
genre = df.set_index("Genre_Name")

# %%
genre.loc["Rock", "Percentage_Sale"]
# Out:
# 53.37773549000951

# %%
for gen in genre.index:
    label = str(round(genre.loc[gen, "Percentage_Sale"],2)) + "%"
    x = genre.loc[gen, "Total_Sales"]
    plt.annotate(label, (x+10, i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8a29825d2d78> in <module>
#       2     label = str(round(genre.loc[gen, "Percentage_Sale"],2)) + "%"
#       3     x = genre.loc[gen, "Total_Sales"]
# ----> 4     plt.annotate(label, (x+10, i))
#
# NameError: name 'i' is not defined

# %%
# ax.text(575,0,str(53.38)+"%" )

plt.annotate(str(53.38)+"%", (575,0))
# Out:
# Text(575, 0, '53.38%')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
# ...

# %%
for i in enumerate(genre.index):
    print(i)
# Out:
# (0, 'Rock')
# (1, 'Alternative & Punk')
# (2, 'Metal')
# (3, 'R&B/Soul')
# (4, 'Blues')
# (5, 'Alternative')
# (6, 'Pop')
# (7, 'Latin')
# (8, 'Hip Hop/Rap')
# (9, 'Jazz')

# %%
for i, gen in enumerate(genre.index):
    per = round(genre.loc[gen, "Percentage_Sale"],2)
    print(per)
# Out:
# 53.38
# 12.37
# 11.8
# 5.04
# 3.43
# 3.33
# 2.09
# 2.09
# 1.9
# 1.33

# %%
genre["Total_Sales"].plot.barh(title = "US Sales", xlim = (0,700), colormap = plt.cm.Accent)
for i, gen in enumerate(genre.index):
    label = str(round(genre.loc[gen, "Percentage_Sale"],1)) + "%"
    x = genre.loc[gen, "Total_Sales"]
    plt.annotate(label, (x+10, i-0.05))
plt.ylabel("")
plt.show()

# %%
q = """with sales_table as
        (select e.first_name || ' ' || e.last_name Employee_Name, e.hire_date Hire_Date,
        i.total Total
        from employee e
        inner join customer c
        on
        e.employee_id = c.support_rep_id
        inner join invoice i
        on
        c.customer_id = i.customer_id)
        
        select Employee_name,Hire_Date,sum(Total) Total_sales from sales_table
        group by 1
        order by 3 desc
        """

read_sql(q)
# Out:
#    Employee_Name            Hire_Date  Total_sales
# 0   Jane Peacock  2017-04-01 00:00:00      1731.51
# 1  Margaret Park  2017-05-03 00:00:00      1584.00
# 2  Steve Johnson  2017-10-17 00:00:00      1393.92

# %%
((1731.51-1393.92)/1731.51)*100
# Out:
# 19.496855345911946

# %%
((1731.51-1584.00)/1731.51)*100
# Out:
# 8.51915380217267

# %%
read_sql("""Pragma table_info(employee)""")
# Out:
#     cid         name          type  notnull dflt_value  pk
# 0     0  employee_id       INTEGER        1       None   1
# 1     1    last_name  NVARCHAR(20)        1       None   0
# 2     2   first_name  NVARCHAR(20)        1       None   0
# 3     3        title  NVARCHAR(30)        0       None   0
# 4     4   reports_to       INTEGER        0       None   0
# 5     5    birthdate      DATETIME        0       None   0
# 6     6    hire_date      DATETIME        0       None   0
# 7     7      address  NVARCHAR(70)        0       None   0
# 8     8         city  NVARCHAR(40)        0       None   0
# 9     9        state  NVARCHAR(40)        0       None   0
# 10   10      country  NVARCHAR(40)        0       None   0
# 11   11  postal_code  NVARCHAR(10)        0       None   0
# 12   12        phone  NVARCHAR(24)        0       None   0
# 13   13          fax  NVARCHAR(24)        0       None   0
# 14   14        email  NVARCHAR(60)        0       None   0

# %%
# call jen

# %%
q = """select first_name  ||' '|| last_name Customer_Name, phone Phone_No from customer
        where first_name like '%jen%' """

read_sql(q)
# Out:
#        Customer_Name           Phone_No
# 0  Jennifer Peterson  +1 (604) 688-2255

# %%
# How many albums and indivisual tracks were sold 
# Out of 614 issued invoices ?

# ** UNION joins tables row-wise, whereas JOIN functions
# join tables column wise

q="""with 

       first_track  as (select invoice_id, track_id
       From invoice_line
       group by 1),
       
       album_p as (
       
       select ft.*, case 
       when 
    (
       select t.track_id from track t
       where t.album_id = (select t2.album_id from track t2
       where t2.track_id = ft.track_id)
       
       Except
       
       select il2.track_id from invoice_line il2
       where il2.invoice_id = ft.invoice_id
       ) is Null
       
       and 
       
       (
        select il2.track_id from invoice_line il2
       where il2.invoice_id = ft.invoice_id
       
       Except
       
      select t.track_id from track t
       where t.album_id = (select t2.album_id from track t2
       where t2.track_id = ft.track_id)
       ) 
       is Null
       then "Yes"
       else "NO"
       end as Album_purchased
       from first_track ft
       )
       
       select Album_purchased, count(invoice_id) number_of_invoces from album_p
       group by 1
         
       """

read_sql(q)
# Out:
#   Album_purchased  number_of_invoces
# 0              NO                500
# 1             Yes                114

# %%
(1158
 Except 
 1158)

is Null

and 

(1158
Except
1158)

is Null

Yes
# Out:
#   File "<ipython-input-31-6c0db982690d>", line 2
#     Except
#     ^
# SyntaxError: invalid syntax

# %%
q = '''select * from customer c
        left join invoice i
        on i.customer_id = c.customer_id
        '''
read_sql(q)

# %%
# country, total_customer, total_sales, avg_order, life_time_vale
q = """with

       c_d as (Select c.country, count(distinct(i.customer_id)) total_cst,
       sum(i.total) tot_sales, sum(i.total)/count(i.customer_id) avg_order,
       sum(total)/count(distinct(i.customer_id)) life_time_value
       from customer c
      left join invoice i
      on i.customer_id = c.customer_id
      group by 1),
      
     updated as ( select case
      when total_cst =1 then "others"
      else country
      end as country, total_cst,
      tot_sales,avg_order,life_time_value
      from c_d),
      
      final as (select country, sum(total_cst) total_cst,
      sum(tot_sales) tot_sales, 
      sum(avg_order)/count(avg_order) as avg_order,
      sum(life_time_value)/count(life_time_value) life_time_value
      from updated
      group by 1),
      
      latest  as (select *, case 
      when country = "others"
      then 0
      else 1
      end as ord
      from final
      order by 6 desc, tot_sales Desc)
      
      select country,total_cst,tot_sales,avg_order,life_time_value
      from latest
      """

read_sql(q)
# Out:
#           country  total_cst  tot_sales  avg_order  life_time_value
# 0             USA         13    1040.49   7.942672        80.037692
# 1          Canada          8     535.59   7.047237        66.948750
# 2          Brazil          5     427.68   7.011148        85.536000
# 3          France          5     389.07   7.781400        77.814000
# 4         Germany          4     334.62   8.161463        83.655000
# 5  Czech Republic          2     273.24   9.108000       136.620000
# 6  United Kingdom          3     245.52   8.768571        81.840000
# 7        Portugal          2     185.13   6.383793        92.565000
# 8           India          2     183.15   8.721429        91.575000
# 9          others         15    1094.94   7.445071        72.996000

# %%
df = read_sql(q)

# %%
df.head()
# Out:
#    country  total_cst  tot_sales  avg_order  life_time_value
# 0      USA         13    1040.49   7.942672        80.037692
# 1   Canada          8     535.59   7.047237        66.948750
# 2   Brazil          5     427.68   7.011148        85.536000
# 3   France          5     389.07   7.781400        77.814000
# 4  Germany          4     334.62   8.161463        83.655000

# %%
country = df.set_index("country")
country.index.name = None

# %%
country.head()
# Out:
#          total_cst  tot_sales  avg_order  life_time_value
# USA             13    1040.49   7.942672        80.037692
# Canada           8     535.59   7.047237        66.948750
# Brazil           5     427.68   7.011148        85.536000
# France           5     389.07   7.781400        77.814000
# Germany          4     334.62   8.161463        83.655000

# %%
import matplotlib.pyplot as plt

# %%
# fig = plt.figure(figsize = (9,10))

# ax1 = fig.add_subplot(2,2,1)
# ax2 = fig.add_subplot(2,2,4)
# ax1 = fig.add_subplot(2,2,3)
# ax1 = fig.add_subplot(2,2,2)

# %%
colors = [plt.cm.Accent(i) for i in np.linspace(0,1, country.shape[0])]

# %%
fig, ax = plt.subplots(nrows = 2,ncols = 2, figsize = (9,10))
ax1,ax2, ax3, ax4 = ax.flatten()
plt.subplots_adjust(hspace = 0.3, wspace = 0.5)

# top left
sales = country["tot_sales"]
sales.plot.pie(ax = ax1, colormap = plt.cm.Accent, title = "Sales", 
               fontsize = 8,
              startangle = -90, counterclock = False)
plt.ylabel("")


# top right

cols = ["total_cst","tot_sales"]

c_s = country[cols].copy()

for c in cols:
    c_s[c] = c_s[c]/sum(c_s[c])
c_s.plot.bar(ax = ax2, rot = 45, colormap = plt.cm.Set1)
ax2.legend(loc= "upper center")
ax2.tick_params(left = False, bottom = False)
for i in ["top", "right"]:
    ax2.spines[i].set_visible(False)

# bottom left
avg_ord = country["avg_order"].copy()

avg_ord = (avg_ord*100/avg_ord.mean())-100


avg_ord.plot.bar(ax = ax3, color = colors)
ax3.axhline(0, alpha = 0.3, color = "k")
plt.show()

# bottom right
